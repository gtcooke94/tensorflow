# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'originated', 'as', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.675273
# Nearest to so: lifespan, polski, successive, waveforms, sodom, impressionistic, ene, bbci,
# Nearest to UNK: alleys, valentinians, gos, ultrasonic, unpleasant, thar, gemstones, engenders,
# Nearest to six: marmite, pisa, clp, gallico, redeem, restitution, quranic, hypothesised,
# Nearest to one: cast, boudinot, lupercalia, cured, teen, veracity, crankshaft, gentler,
# Nearest to are: samhain, opium, mcclory, resettle, intermixed, lillian, weavers, danelaw,
# Nearest to when: katana, addiction, aran, structures, subfield, diu, pooh, gadget,
# Nearest to over: anglicisation, accomplish, benzodiazepine, remember, pm, graduated, jutland, gaius,
# Nearest to years: finishes, cynthia, wirth, topography, gibbon, two, halogens, osteoporosis,
# Nearest to at: ifad, concedes, livius, victories, fuerteventura, geiger, bayern, predominated,
# Nearest to can: siddhartha, prd, regulated, rcn, sim, baruch, scroll, interior,
# Nearest to five: dn, rathdown, vipers, jarring, hysteresis, damnation, mumps, cernunnos,
# Nearest to were: resides, pohl, whole, anecdote, replacing, kate, tutor, tanker,
# Nearest to state: lovin, z, normalize, dispatched, transposition, huggins, guessing, charms,
# Nearest to into: waitress, maximin, planks, minimax, coli, competences, legate, residuals,
# Nearest to had: hamlet, microarchitecture, encha, speller, unlikely, smuggler, pdg, mesons,
# Nearest to four: flamenco, sorel, adhesive, melito, ecowas, ivor, ut, qxd,
# Average loss at step 2000: 4.374219
# Average loss at step 4000: 3.869382
# Average loss at step 6000: 3.783784
# Average loss at step 8000: 3.685062
# Average loss at step 10000: 3.618757
# Nearest to so: successive, sodom, performance, if, marinus, cfp, earthworms, newcomer,
# Nearest to UNK: judo, walken, pocketing, meshech, le, codec, kabul, database,
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Nearest to one: two, three, seven, five, four, six, eight, orchid,
# Nearest to are: were, is, have, opium, was, include, can, but,
# Nearest to when: katana, mysql, retirement, addiction, structures, universality, pooh, scandals,
# Nearest to over: pm, mumonkan, escuela, soar, pinnacle, navigation, anglicisation, kharkov,
# Nearest to years: finishes, cynthia, architecture, gibbon, cares, topography, printed, masjid,
# Nearest to at: bayern, in, airfields, steroid, raphaelite, fuerteventura, victories, hercules,
# Nearest to can: would, may, could, should, will, interior, are, diner,
# Nearest to five: four, eight, six, three, seven, nine, two, zero,
# Nearest to were: are, was, have, opus, had, pohl, opium, resides,
# Nearest to state: extramarital, lump, foes, center, z, fierce, evenly, linus,
# Nearest to into: waitress, maximin, minimax, residuals, coli, legate, exponential, stick,
# Nearest to had: has, have, speller, was, were, dalit, rico, became,
# Nearest to four: five, three, six, seven, eight, two, nine, zero,
# Average loss at step 12000: 3.599970
# Average loss at step 14000: 3.578475
# Average loss at step 16000: 3.414426
# Average loss at step 18000: 3.458314
# Average loss at step 20000: 3.544729
# Nearest to so: successive, note, if, performance, sodom, benefited, berkelium, seasons,
# Nearest to UNK: ralston, polysaccharide, judo, induction, speculative, angeles, maul, managers,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to one: two, four, three, seven, eight, six, five, nine,
# Nearest to are: were, is, have, opium, was, can, include, opus,
# Nearest to when: if, under, where, scandals, though, mysql, but, during,
# Nearest to over: escuela, soar, pinnacle, buckley, between, supplies, quite, navigation,
# Nearest to years: finishes, times, cares, cynthia, topography, architecture, tons, deflate,
# Nearest to at: in, during, on, from, hercules, with, after, steroid,
# Nearest to can: may, would, could, should, will, cannot, might, must,
# Nearest to five: three, four, six, seven, eight, two, zero, nine,
# Nearest to were: are, was, had, have, by, opus, be, being,
# Nearest to state: foes, fierce, center, lump, hosting, right, avenues, request,
# Nearest to into: from, legate, waitress, by, minimax, maximin, residuals, improbable,
# Nearest to had: has, have, was, were, speller, lightest, rico, though,
# Nearest to four: eight, three, six, seven, five, two, nine, zero,
# Average loss at step 22000: 3.502850
# Average loss at step 24000: 3.491269
# Average loss at step 26000: 3.482955
# Average loss at step 28000: 3.479441
# Average loss at step 30000: 3.505524
# Nearest to so: note, if, sodom, berkelium, not, youssef, cfp, archimedean,
# Nearest to UNK: induction, admiral, pocketing, http, managers, dunst, emily, al,
# Nearest to six: eight, four, nine, seven, five, three, two, zero,
# Nearest to one: two, seven, four, three, five, eight, nine, six,
# Nearest to are: were, is, have, include, those, but, syllabics, habitability,
# Nearest to when: if, under, before, where, though, after, but, was,
# Nearest to over: perkin, between, into, escuela, telegraphy, supplies, searchlight, soar,
# Nearest to years: times, months, tons, architecture, cynthia, differentiability, cares, topography,
# Nearest to at: during, in, after, on, noether, livius, since, steroid,
# Nearest to can: may, would, could, will, should, cannot, might, must,
# Nearest to five: four, eight, six, seven, three, nine, zero, two,
# Nearest to were: are, was, had, have, be, being, been, almonds,
# Nearest to state: fierce, lump, states, polymorphism, center, foes, linus, hosting,
# Nearest to into: from, legate, through, under, waitress, maximin, on, residuals,
# Nearest to had: have, has, was, were, speller, having, hangul, rico,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Average loss at step 32000: 3.499533
# Average loss at step 34000: 3.494155
# Average loss at step 36000: 3.454329
# Average loss at step 38000: 3.299440
# Average loss at step 40000: 3.429651
# Nearest to so: note, sodom, not, if, performance, poisoned, claim, bottlers,
# Nearest to UNK: b, arion, barn, d, veeck, porvoo, johnson, calatrava,
# Nearest to six: four, eight, seven, five, three, nine, two, one,
# Nearest to one: seven, two, six, four, eight, nine, five, three,
# Nearest to are: were, include, is, have, those, but, be, cried,
# Nearest to when: if, where, before, though, under, bce, after, although,
# Nearest to over: telegraphy, between, escuela, carols, soar, stretched, searchlight, waitress,
# Nearest to years: times, months, days, baikal, galahad, differentiability, tons, decades,
# Nearest to at: during, on, in, venture, after, steroid, livius, dirichlet,
# Nearest to can: may, could, will, would, should, cannot, might, must,
# Nearest to five: six, seven, four, three, eight, nine, zero, two,
# Nearest to were: are, was, have, being, been, had, be, almonds,
# Nearest to state: states, foes, storyteller, lump, hosting, fierce, request, zedong,
# Nearest to into: legate, from, through, residuals, waitress, constitutes, on, charlestown,
# Nearest to had: has, have, was, speller, were, orientational, hangul, having,
# Nearest to four: six, three, five, eight, seven, two, nine, one,
# Average loss at step 42000: 3.435559
# Average loss at step 44000: 3.452845
# Average loss at step 46000: 3.449158
# Average loss at step 48000: 3.348917
# Average loss at step 50000: 3.389252
# Nearest to so: note, motala, when, cursus, if, higher, diss, schottky,
# Nearest to UNK: induction, judo, cephalon, de, portal, speculative, baptizing, tudes,
# Nearest to six: eight, seven, four, five, nine, three, two, one,
# Nearest to one: two, six, eight, seven, four, nine, five, three,
# Nearest to are: were, is, have, include, these, be, those, although,
# Nearest to when: if, where, before, while, though, after, until, although,
# Nearest to over: between, telegraphy, escuela, plosive, embarking, inherits, kampuchea, buckley,
# Nearest to years: days, times, months, galahad, year, decades, baikal, tons,
# Nearest to at: during, sena, ingested, on, whereby, from, steroid, madly,
# Nearest to can: may, could, will, would, should, cannot, might, must,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to were: are, was, have, had, been, be, being, although,
# Nearest to state: foes, states, storyteller, lump, hosting, fierce, symphonies, center,
# Nearest to into: through, legate, from, residuals, across, waitress, under, within,
# Nearest to had: has, have, was, having, were, been, orientational, since,
# Nearest to four: six, eight, five, seven, three, nine, two, zero,
# Average loss at step 52000: 3.438954
# Average loss at step 54000: 3.428628
# Average loss at step 56000: 3.441796
# Average loss at step 58000: 3.399760
# Average loss at step 60000: 3.394683
# Nearest to so: if, when, schottky, too, diss, whether, note, motala,
# Nearest to UNK: sodom, speculative, cliff, raven, carracci, topics, identical, upcoming,
# Nearest to six: eight, five, four, nine, seven, three, two, one,
# Nearest to one: four, six, eight, two, seven, nine, three, five,
# Nearest to are: were, have, include, is, habitability, those, aspectual, although,
# Nearest to when: if, before, where, during, although, after, though, while,
# Nearest to over: telegraphy, between, into, glance, rejoicing, plosive, within, searchlight,
# Nearest to years: days, times, months, decades, galahad, baikal, year, centuries,
# Nearest to at: during, in, after, steroid, livius, within, madly, dirichlet,
# Nearest to can: may, could, will, would, cannot, should, might, must,
# Nearest to five: six, four, three, eight, seven, nine, zero, two,
# Nearest to were: are, was, had, have, although, been, syllabics, be,
# Nearest to state: foes, states, storyteller, lump, nugget, government, hosting, city,
# Nearest to into: through, legate, from, across, within, residuals, under, over,
# Nearest to had: has, have, was, having, were, been, did, lasers,
# Nearest to four: five, eight, six, seven, three, nine, two, zero,
# Average loss at step 62000: 3.244725
# Average loss at step 64000: 3.253507
# Average loss at step 66000: 3.406208
# Average loss at step 68000: 3.398519
# Average loss at step 70000: 3.363101
# Nearest to so: when, too, whether, schottky, inclusive, sometimes, otaku, thus,
# Nearest to UNK: superfund, pocketing, arion, distort, equalizer, monday, wu, vowels,
# Nearest to six: eight, seven, nine, five, four, three, two, zero,
# Nearest to one: seven, two, six, four, eight, five, nine, three,
# Nearest to are: were, include, is, have, these, although, frisia, including,
# Nearest to when: if, however, where, before, though, while, although, after,
# Nearest to over: about, rejoicing, telegraphy, between, glance, through, nauru, into,
# Nearest to years: days, months, times, decades, centuries, year, weeks, baikal,
# Nearest to at: during, after, livius, dirichlet, near, batll, asmara, without,
# Nearest to can: may, could, will, would, cannot, must, should, might,
# Nearest to five: four, six, three, seven, nine, eight, zero, two,
# Nearest to were: are, was, had, have, be, been, include, being,
# Nearest to state: foes, states, city, government, lump, storyteller, town, hallowed,
# Nearest to into: legate, through, from, across, residuals, waitress, with, under,
# Nearest to had: has, have, was, were, having, lasers, rico, been,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Average loss at step 72000: 3.376855
# Average loss at step 74000: 3.349994
# Average loss at step 76000: 3.319134
# Average loss at step 78000: 3.352919
# Average loss at step 80000: 3.379142
# Nearest to so: when, then, too, darussalam, balfour, otaku, inclusive, whether,
# Nearest to UNK: ed, mathematician, tudes, wilson, affectation, le, bulky, i,
# Nearest to six: four, five, eight, seven, three, nine, two, one,
# Nearest to one: seven, six, two, four, eight, three, five, nine,
# Nearest to are: were, include, have, is, although, these, those, including,
# Nearest to when: if, before, after, though, where, during, although, however,
# Nearest to over: between, within, around, rejoicing, into, about, nauru, across,
# Nearest to years: months, days, times, decades, year, centuries, weeks, bc,
# Nearest to at: during, in, on, arbor, within, steroid, bayern, livius,
# Nearest to can: may, will, could, would, cannot, should, must, might,
# Nearest to five: four, six, eight, seven, three, nine, two, zero,
# Nearest to were: are, was, had, have, been, those, being, be,
# Nearest to state: foes, city, states, hallowed, government, town, continent, pressured,
# Nearest to into: through, from, legate, across, within, residuals, with, over,
# Nearest to had: has, have, were, was, having, been, rico, mujahedin,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Average loss at step 82000: 3.406446
# Average loss at step 84000: 3.407673
# Average loss at step 86000: 3.394858
# Average loss at step 88000: 3.355109
# Average loss at step 90000: 3.370176
# Nearest to so: thus, if, motala, showed, too, diss, when, then,
# Nearest to UNK: tudes, viridian, phosphide, vitreous, speculative, amalric, decadent, dieting,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to one: seven, four, eight, two, three, five, six, nine,
# Nearest to are: were, is, include, have, these, although, aspectual, those,
# Nearest to when: if, where, before, though, after, while, until, during,
# Nearest to over: within, around, nauru, between, across, about, rejoicing, virginals,
# Nearest to years: days, months, times, decades, centuries, year, weeks, bc,
# Nearest to at: during, under, after, on, whereby, madly, near, in,
# Nearest to can: could, may, will, cannot, would, should, might, must,
# Nearest to five: seven, eight, four, three, six, two, nine, zero,
# Nearest to were: are, was, had, have, while, being, been, those,
# Nearest to state: city, foes, states, hallowed, lump, pressured, storyteller, levels,
# Nearest to into: through, from, legate, across, within, under, residuals, with,
# Nearest to had: has, have, was, having, were, mujahedin, lasers, been,
# Nearest to four: seven, five, three, eight, six, two, nine, one,
# Average loss at step 92000: 3.398974
# Average loss at step 94000: 3.253784
# Average loss at step 96000: 3.361362
# Average loss at step 98000: 3.245937
# Average loss at step 100000: 3.355476
# Nearest to so: too, thus, motala, then, darussalam, if, when, showed,
# Nearest to UNK: tudes, dunst, meshech, choirs, mathematically, belvedere, outlet, vowels,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to one: two, four, seven, eight, five, three, nine, six,
# Nearest to are: were, have, those, is, be, include, although, these,
# Nearest to when: if, where, though, although, after, before, while, during,
# Nearest to over: within, around, accusing, massing, virginals, between, nauru, across,
# Nearest to years: days, months, times, decades, year, centuries, weeks, minutes,
# Nearest to at: during, after, on, in, within, near, under, eg,
# Nearest to can: may, could, will, would, should, cannot, must, might,
# Nearest to five: four, seven, six, eight, three, nine, two, zero,
# Nearest to were: are, have, was, those, had, these, grabs, being,
# Nearest to state: city, foes, pressured, hallowed, lump, states, boer, fierce,
# Nearest to into: through, legate, from, across, within, residuals, back, upon,
# Nearest to had: has, have, was, having, were, speller, islander, lasers,
# Nearest to four: seven, six, five, eight, three, two, nine, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# Data associated with a label is a vector of each surrounding word rather than one-to-one mappings:
# i.e. for [the, dog, barked, at, a, tree]
# skip-gram 2, 1 gets something like [dog, the], [dog, barked], [barked, dog], [barked, at]
# CBOW gets something like [dog, [the barked]], [barked, [dog at]] etc.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# # Make a batch

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    global data_index
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.ndarray)

    for i in range(batch_size):
        buffer = list()
        span_index = data_index
        for _ in range(span):
            buffer.append(data[span_index])
            span_index = (span_index + 1) % len(data)
        target = len(buffer) // 2 # the middle element of the buffer
        #batch_add = np.ndarray(shape=(span - 1), dtype=np.int32)
        to_add = buffer[:target]
        to_add.extend(buffer[(target+1):])
        #batch_add[:] = to_add
        #batch[i] = batch_add
        batch[i, :] = to_add
        labels[i] = buffer[target]
        data_index = (data_index + 1) % len(data)
    labels = labels.reshape(len(labels), 1)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    labels = labels.flatten()
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    for i in range(len(batch)):
        print('label: ', reverse_dictionary[labels[i]])
        print('batch: ', [reverse_dictionary[bi] for bi in batch[i]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
# label:  originated
# batch:  ['anarchism', 'as']
# label:  as
# batch:  ['originated', 'a']
# label:  a
# batch:  ['as', 'term']
# label:  term
# batch:  ['a', 'of']
# label:  of
# batch:  ['term', 'abuse']
# label:  abuse
# batch:  ['of', 'first']
# label:  first
# batch:  ['abuse', 'used']
# label:  used
# batch:  ['first', 'against']
#
# with num_skips = 2 and skip_window = 2:
# label:  as
# batch:  ['anarchism', 'originated', 'a', 'term']
# label:  a
# batch:  ['originated', 'as', 'term', 'of']
# label:  term
# batch:  ['as', 'a', 'of', 'abuse']
# label:  of
# batch:  ['a', 'term', 'abuse', 'first']
# label:  abuse
# batch:  ['term', 'of', 'first', 'used']
# label:  first
# batch:  ['of', 'abuse', 'used', 'against']
# label:  used
# batch:  ['abuse', 'first', 'against', 'early']
# label:  against
# batch:  ['first', 'used', 'early', 'working']

# %% [markdown]
# ## Setup the network

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # More complicated for CBOW
  # BEFORE:
  #embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # AFTER:
  # Get embedding for each word associated with label, average them
  # http://www.thushv.com/natural_language_processing/word2vec-part-2-nlp-with-deep-learning-with-tensorflow-cbow/
  # https://github.com/ankit-ai/udacity_deep_learning_course/blob/master/5_word2vec.ipynb
  #embeds = None
  #for i in range(2 * skip_window):
  #  embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:, i])
  #  print('embedding %d shape: %s'%(i,embedding_i.get_shape().as_list()))
  #  emb_x,emb_y = embedding_i.get_shape().as_list()
  #  if embeds is None:
  #      embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
  #  else:
  #      embeds = tf.concat(2,[embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])])
  # Averaging embeddings accross the full context into a single embedding layer
  context_embeddings = []
  for i in range(2*skip_window):
    context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]))
            
  avg_embed =  tf.reduce_mean(tf.stack(axis=0,values=context_embeddings),0,keep_dims=False) 

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %% [markdown]
# ## Train the model

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.734613
# Nearest to united: mouthpieces, mcculloch, lozada, elf, present, tories, potatoes, rerio,
# Nearest to with: platonism, monterey, offence, chinese, tupolev, inaccuracies, order, noticed,
# Nearest to a: activation, niue, magnets, anatomy, misc, refugee, sepulchre, access,
# Nearest to these: promoters, sums, syndicates, citations, leveling, havelock, leases, fung,
# Nearest to people: eigenvectors, copy, adventurer, surfin, vein, haaretz, thrives, dubious,
# Nearest to such: flattened, boaz, styles, antiquaries, djbdns, std, brixton, estates,
# Nearest to but: spacecraft, woods, nikola, subtle, co, eritrea, galilee, vulgaris,
# Nearest to only: erythrocytes, insults, futuna, aster, ken, broker, encourage, alderman,
# Nearest to this: deportations, hemispheric, railhead, steward, kenyan, tender, bogomils, imperium,
# Nearest to be: britannica, starvation, nostrils, vasily, giscard, soaking, brubeck, spate,
# Nearest to see: seifert, bugatti, autocad, deeply, luncheon, ashur, havilland, eurotunnel,
# Nearest to been: langevin, amounts, mieszko, monty, hobson, tunable, boring, miggins,
# Nearest to many: charlottenburg, dissociative, minimise, judd, camilo, commemorate, trapezohedron, botanic,
# Nearest to states: vacated, judd, hawker, magnificent, ramakrishna, ratites, compilation, societies,
# Nearest to most: gallic, decomposers, teachings, meridians, helene, altair, silla, looted,
# Nearest to it: dull, fmd, lucid, galil, mulligan, pid, signed, dupont,
# Average loss at step 2000: 4.032293
# Average loss at step 4000: 3.513156
# Average loss at step 6000: 3.321355
# Average loss at step 8000: 3.216436
# Average loss at step 10000: 3.132573
# Nearest to united: mouthpieces, progressed, acetylcholine, present, wildcat, potatoes, tories, lozada,
# Nearest to with: pero, against, in, chinese, noticed, procedure, for, postings,
# Nearest to a: the, estimator, distinguishable, activation, shea, any, sena, truso,
# Nearest to these: some, wollheim, untimely, gion, bsa, swamps, seminole, hailstones,
# Nearest to people: non, crush, vein, surfin, wangenheim, masovia, devoured, wife,
# Nearest to such: well, hemingway, laconic, std, large, aneurin, imagine, bunt,
# Nearest to but: rence, and, green, woods, dek, hymnal, spacecraft, tsui,
# Nearest to only: utopian, futuna, ward, erythrocytes, runs, starvation, slid, reporter,
# Nearest to this: the, it, their, wave, fatou, which, unimpeded, every,
# Nearest to be: have, is, vulcan, chr, was, soaking, sachet, molten,
# Nearest to see: marketplace, luncheon, maldives, multiplication, dendritic, baresi, deeply, havilland,
# Nearest to been: was, pxe, dq, idealists, always, alexandrian, had, diagonally,
# Nearest to many: some, all, charlottenburg, minimise, other, several, standout, those,
# Nearest to states: exterminating, magnificent, walras, hengest, xxxv, instituting, vacated, job,
# Nearest to most: foulke, thru, gallic, knowledge, bilingualism, silla, filk, warships,
# Nearest to it: he, there, this, she, whyte, dull, subtraction, bai,
# Average loss at step 12000: 3.149081
# Average loss at step 14000: 3.136412
# Average loss at step 16000: 3.120586
# Average loss at step 18000: 3.110740
# Average loss at step 20000: 2.982508
# Nearest to united: mouthpieces, progressed, present, tories, acetylcholine, wildcat, lozada, potatoes,
# Nearest to with: against, platonism, pero, enzyme, cartographic, procedure, chinese, noticed,
# Nearest to a: magnets, another, shea, distinguishable, communicating, scoping, the, any,
# Nearest to these: some, such, many, zolt, those, which, workstations, abdal,
# Nearest to people: non, splinter, officeholders, zimmerman, autumn, devoured, emmerdale, years,
# Nearest to such: well, these, imagine, std, mimi, many, bunt, badlands,
# Nearest to but: however, and, rence, dek, georgian, since, tsui, spacecraft,
# Nearest to only: utopian, ward, futuna, kiel, runs, reporter, montmartre, preserved,
# Nearest to this: it, which, that, what, the, deportations, wave, overheating,
# Nearest to be: have, been, is, were, was, molten, produce, chr,
# Nearest to see: dendritic, luncheon, marketplace, multiplication, labour, impious, deeply, havilland,
# Nearest to been: be, was, alexandrian, become, idealists, loire, dq, were,
# Nearest to many: some, several, all, charlottenburg, various, those, these, minimise,
# Nearest to states: exterminating, magnificent, belarus, dpp, ramakrishna, hawker, instituting, job,
# Nearest to most: more, foulke, thru, gallic, many, works, less, bilingualism,
# Nearest to it: he, she, this, there, subfields, whyte, stomp, coprocessor,
# Average loss at step 22000: 3.056527
# Average loss at step 24000: 3.050593
# Average loss at step 26000: 2.971536
# Average loss at step 28000: 3.006834
# Average loss at step 30000: 2.984560
# Nearest to united: mouthpieces, progressed, tories, acetylcholine, present, lozada, leste, murderers,
# Nearest to with: enzyme, procedure, pero, platonism, noticed, corneille, cartographic, pregnancies,
# Nearest to a: the, truso, another, any, estimator, magnets, distinguishable, multiprogramming,
# Nearest to these: some, such, those, zolt, several, many, workstations, antithesis,
# Nearest to people: women, years, ncc, sacro, infogrames, days, ssbauer, individuals,
# Nearest to such: these, well, large, imagine, lawful, analog, many, trustworthy,
# Nearest to but: however, and, nagasaki, dek, since, although, mines, rence,
# Nearest to only: reporter, always, preserved, utopian, ostwald, kiel, runs, still,
# Nearest to this: it, which, the, what, wave, that, pence, overheating,
# Nearest to be: been, was, is, have, being, were, refer, hackett,
# Nearest to see: dendritic, schumacher, marketplace, impious, luncheon, maldives, bugatti, helpers,
# Nearest to been: be, was, become, were, alexandrian, idealists, dq, loire,
# Nearest to many: some, several, various, those, all, most, these, other,
# Nearest to states: exterminating, rationality, belarus, magnificent, holds, job, societies, ramakrishna,
# Nearest to most: more, less, many, some, thru, gallic, anhalt, foulke,
# Nearest to it: he, she, this, there, impede, they, provisionally, whyte,
# Average loss at step 32000: 2.973976
# Average loss at step 34000: 2.810078
# Average loss at step 36000: 2.935409
# Average loss at step 38000: 2.934154
# Average loss at step 40000: 2.919186
# Nearest to united: progressed, mouthpieces, tories, acetylcholine, lozada, cumbria, leste, pharmaceutical,
# Nearest to with: enzyme, between, carrier, against, lodges, platonism, pero, bon,
# Nearest to a: another, the, estimator, multiprogramming, magnets, truso, arrakis, lynching,
# Nearest to these: such, some, those, zolt, several, which, many, various,
# Nearest to people: women, men, ncc, comets, infogrames, individuals, emperors, dethroned,
# Nearest to such: these, well, many, including, carboniferous, lawful, trustworthy, maghrib,
# Nearest to but: however, and, nagasaki, although, mines, traced, petite, hymnal,
# Nearest to only: always, ostwald, reporter, preserved, cooperstown, oppositions, boethius, haggis,
# Nearest to this: it, which, what, fatou, overheating, that, pence, deportations,
# Nearest to be: been, was, being, is, were, become, have, refer,
# Nearest to see: dendritic, shameless, impious, ovaries, bugatti, aficionados, schumacher, marketplace,
# Nearest to been: be, become, was, were, alexandrian, idealists, already, dq,
# Nearest to many: some, several, various, all, most, other, those, these,
# Nearest to states: societies, exterminating, state, holds, job, belarus, kingdom, colons,
# Nearest to most: more, many, some, less, foulke, thru, gallic, jul,
# Nearest to it: he, she, this, there, they, provisionally, odyssey, welcoming,
# Average loss at step 42000: 2.917527
# Average loss at step 44000: 2.958773
# Average loss at step 46000: 2.912228
# Average loss at step 48000: 2.916381
# Average loss at step 50000: 2.834861
# Nearest to united: progressed, mouthpieces, tories, acetylcholine, lozada, cumbria, leste, present,
# Nearest to with: ets, bon, enzyme, chipmunks, between, pero, shou, while,
# Nearest to a: the, estimator, multiprogramming, arrakis, another, shea, scoping, distinguishable,
# Nearest to these: such, those, several, some, many, zolt, various, workstations,
# Nearest to people: women, men, emperors, ncc, comets, individuals, infogrames, confine,
# Nearest to such: these, well, remote, many, lawful, including, maghrib, analog,
# Nearest to but: however, and, although, while, mines, though, visitor, nagasaki,
# Nearest to only: always, preserved, haggis, reporter, oppositions, yet, boethius, cooperstown,
# Nearest to this: it, which, what, the, overheating, canmore, fatou, that,
# Nearest to be: been, is, become, being, was, were, produce, refer,
# Nearest to see: dendritic, includes, korca, ovaries, aficionados, ul, include, bugatti,
# Nearest to been: be, become, was, alexandrian, already, idealists, loire, were,
# Nearest to many: some, several, various, most, all, these, those, fdi,
# Nearest to states: societies, state, kingdom, exterminating, nations, ramakrishna, nicolaus, belarus,
# Nearest to most: more, many, less, some, other, gallic, urim, foulke,
# Nearest to it: he, she, this, there, they, odyssey, soon, what,
# Average loss at step 52000: 2.837077
# Average loss at step 54000: 2.862471
# Average loss at step 56000: 2.882089
# Average loss at step 58000: 2.735682
# Average loss at step 60000: 2.817183
# Nearest to united: progressed, tories, mouthpieces, lozada, acetylcholine, joined, cumbria, leste,
# Nearest to with: between, carrier, maxi, enzyme, fingerspelling, while, raytheon, broch,
# Nearest to a: the, estimator, multiprogramming, another, every, charters, scoping, shea,
# Nearest to these: several, those, such, some, zolt, many, various, which,
# Nearest to people: women, men, children, emperors, economists, individuals, comets, ncc,
# Nearest to such: these, well, including, remote, many, those, carboniferous, herself,
# Nearest to but: however, although, and, though, while, mines, plissken, backside,
# Nearest to only: preserved, always, yet, haggis, still, oppositions, primarily, cooperstown,
# Nearest to this: which, it, overheating, the, what, iie, fatou, canmore,
# Nearest to be: been, become, is, being, produce, was, are, were,
# Nearest to see: includes, dendritic, include, aficionados, luminaries, ul, impious, allows,
# Nearest to been: be, become, was, were, alexandrian, already, idealists, loire,
# Nearest to many: some, several, various, most, all, these, those, few,
# Nearest to states: nations, societies, state, kingdom, rationality, holds, ramakrishna, pune,
# Nearest to most: more, many, less, some, use, urim, gallic, especially,
# Nearest to it: he, she, this, there, they, cricketing, impede, gradually,
# Average loss at step 62000: 2.850332
# Average loss at step 64000: 2.827106
# Average loss at step 66000: 2.715995
# Average loss at step 68000: 2.741993
# Average loss at step 70000: 2.769459
# Nearest to united: progressed, tories, mouthpieces, acetylcholine, leste, joined, european, lozada,
# Nearest to with: between, in, pero, cartographic, enzyme, bon, including, guerrillas,
# Nearest to a: another, the, multiprogramming, any, scoping, estimator, arrakis, ob,
# Nearest to these: those, such, several, some, various, many, zolt, different,
# Nearest to people: women, men, economists, historians, individuals, emperors, children, comets,
# Nearest to such: these, those, remote, well, certain, many, known, including,
# Nearest to but: however, although, and, though, while, see, visitor, kossuth,
# Nearest to only: always, oppositions, cooperstown, haggis, yet, kiel, reporter, just,
# Nearest to this: it, which, what, the, overheating, canmore, fatou, iie,
# Nearest to be: been, become, is, being, was, have, produce, refer,
# Nearest to see: dendritic, includes, but, include, rip, guidebook, aficionados, helpers,
# Nearest to been: be, become, alexandrian, was, were, already, recently, idealists,
# Nearest to many: some, several, various, most, all, numerous, those, these,
# Nearest to states: kingdom, state, nations, societies, holds, rationality, shattuck, exterminating,
# Nearest to most: more, many, less, some, urim, especially, other, use,
# Nearest to it: he, she, there, this, they, soon, welcoming, nothing,
# Average loss at step 72000: 2.750737
# Average loss at step 74000: 2.785608
# Average loss at step 76000: 2.664016
# Average loss at step 78000: 2.793380
# Average loss at step 80000: 2.812764
# Nearest to united: progressed, tories, joined, acetylcholine, leste, lozada, mouthpieces, euro,
# Nearest to with: between, pero, broch, bon, icbms, dunk, enzyme, when,
# Nearest to a: the, multiprogramming, estimator, another, arrakis, any, beit, scoping,
# Nearest to these: those, such, several, some, various, many, zolt, workstations,
# Nearest to people: women, men, historians, economists, emperors, comets, children, scholars,
# Nearest to such: these, remote, certain, those, well, including, known, trustworthy,
# Nearest to but: however, although, and, though, see, plissken, mines, visitor,
# Nearest to only: already, oppositions, primarily, cooperstown, always, haggis, yet, all,
# Nearest to this: it, which, overheating, canmore, what, that, the, fatou,
# Nearest to be: been, is, become, being, produce, was, refer, create,
# Nearest to see: but, includes, dendritic, ul, include, tell, rip, allows,
# Nearest to been: be, become, was, were, alexandrian, already, recently, idealists,
# Nearest to many: several, some, various, numerous, most, those, all, few,
# Nearest to states: state, kingdom, nations, societies, holds, belarus, exterminating, pune,
# Nearest to most: more, many, less, some, urim, particularly, especially, other,
# Nearest to it: he, she, there, this, they, provisionally, nothing, itself,
# Average loss at step 82000: 2.768439
# Average loss at step 84000: 2.684238
# Average loss at step 86000: 2.761454
# Average loss at step 88000: 2.736432
# Average loss at step 90000: 2.751099
# Nearest to united: progressed, tories, joined, lozada, euro, mouthpieces, acetylcholine, leste,
# Nearest to with: between, raytheon, dunk, shou, ets, plus, pregnancies, dries,
# Nearest to a: another, arrakis, multiprogramming, the, estimator, ob, scoping, mapsto,
# Nearest to these: those, such, some, several, various, many, zolt, both,
# Nearest to people: women, men, historians, individuals, children, scholars, comets, persons,
# Nearest to such: these, remote, well, those, certain, lawful, many, known,
# Nearest to but: however, although, though, and, which, see, while, until,
# Nearest to only: cooperstown, primarily, either, haggis, already, just, oppositions, deceptively,
# Nearest to this: which, it, canmore, fatou, escorts, overheating, that, what,
# Nearest to be: been, become, being, was, refer, is, produce, exhibit,
# Nearest to see: includes, dendritic, include, but, list, ul, teach, shameless,
# Nearest to been: be, become, were, was, alexandrian, idealists, already, remained,
# Nearest to many: some, several, various, numerous, most, all, few, both,
# Nearest to states: nations, state, kingdom, societies, countries, belarus, ramakrishna, motorsport,
# Nearest to most: more, many, less, some, particularly, especially, urim, extremely,
# Nearest to it: he, she, there, this, they, nothing, provisionally, itself,
# Average loss at step 92000: 2.746682
# Average loss at step 94000: 2.667050
# Average loss at step 96000: 2.736723
# Average loss at step 98000: 2.697734
# Average loss at step 100000: 2.459855
# Nearest to united: progressed, tories, euro, acetylcholine, squarely, joined, lozada, leste,
# Nearest to with: between, bon, broch, clump, wavelet, via, grahame, when,
# Nearest to a: another, arrakis, multiprogramming, estimator, the, mapsto, scoping, communicating,
# Nearest to these: those, such, several, some, various, zolt, workstations, many,
# Nearest to people: women, men, individuals, historians, children, emperors, comets, persons,
# Nearest to such: these, remote, certain, well, those, known, including, trustworthy,
# Nearest to but: however, although, though, see, which, and, kossuth, minimi,
# Nearest to only: oppositions, cooperstown, haggis, reporter, primarily, either, rutskoy, deceptively,
# Nearest to this: which, it, canmore, fatou, overheating, what, mbeki, each,
# Nearest to be: been, become, being, is, was, produce, were, refer,
# Nearest to see: includes, dendritic, include, but, list, allows, called, ul,
# Nearest to been: be, become, was, alexandrian, were, already, idealists, remained,
# Nearest to many: several, some, various, numerous, few, most, all, those,
# Nearest to states: state, nations, kingdom, societies, belarus, countries, us, pune,
# Nearest to most: more, many, less, some, particularly, especially, use, urim,
# Nearest to it: he, she, there, they, this, nothing, soon, gradually,

# %%
from sklearn.manifold import TSNE
num_points = 400
# Try other inits, other n_iter
tsne = TSNE(init='pca')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
