# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.188881
# Nearest to been: disenchantment, reconciled, notion, khan, hoddle, formally, nayla, cartwright,
# Nearest to if: bullfighting, stags, baraka, suggest, lago, westermann, kamehameha, shepherd,
# Nearest to first: com, winston, anesthetic, sms, subsisting, rapport, holomorphic, certain,
# Nearest to no: acrobatics, legionaries, staphylococcus, verses, trismegistus, tsunamis, monterey, fourths,
# Nearest to the: gianfranco, basses, discontinuous, ghosts, dictating, witte, ldots, winnipeg,
# Nearest to new: equator, spring, attractor, howie, intrigue, typographic, novellas, devises,
# Nearest to called: disparagingly, heh, steinbeck, moria, homininae, pity, mujibur, rumble,
# Nearest to his: rhead, merril, predetermined, buyout, prostaglandins, apostle, bestiaries, default,
# Nearest to over: compelling, corrections, conventions, spate, liners, dragons, methyl, agnostic,
# Nearest to after: neglecting, advocacy, faculty, differentiating, rounding, resurfaced, monophosphate, incarceration,
# Nearest to most: sharpened, stepmania, blotting, falstaff, fe, phelps, surrealism, trypanosoma,
# Nearest to history: vorbis, philosopher, disjunction, swelled, militar, biqa, smuggler, deterioration,
# Nearest to two: kiss, lauren, timepieces, emblems, biases, ticker, lfc, seduction,
# Nearest to may: rockall, handfasting, agesilaus, annular, residues, marginalized, lutes, bahasa,
# Nearest to that: governorate, treviso, drawer, petrel, expensive, judean, dollar, marlow,
# Nearest to often: abatis, positions, protoscience, muon, inputs, resurgent, vitae, nearest,
# Average loss at step 2000: 4.373356
# Average loss at step 4000: 3.861001
# Average loss at step 6000: 3.791178
# Average loss at step 8000: 3.684522
# Average loss at step 10000: 3.614030
# Nearest to been: by, fodder, painting, mora, regained, students, be, heightened,
# Nearest to if: bullfighting, wrote, abdominal, although, masefield, suggest, lusitania, purview,
# Nearest to first: anesthetic, sms, during, slow, jews, dye, winston, rj,
# Nearest to no: it, legionaries, distracting, brest, who, verses, this, staphylococcus,
# Nearest to the: a, its, this, his, their, preparation, bayezid, muskets,
# Nearest to new: equator, howie, livelihood, fearing, spl, cold, curving, overtaken,
# Nearest to called: douglass, garage, denumerable, unfriendly, rugby, thick, dayton, canadian,
# Nearest to his: their, the, her, its, s, buyout, ern, preparation,
# Nearest to over: corrections, crespigny, plaintexts, conventions, seif, globalsecurity, histogram, greenlandic,
# Nearest to after: inquart, corrective, pacifist, pln, contract, numidia, in, duality,
# Nearest to most: fe, mortis, phelps, offline, numidia, wither, narmada, varying,
# Nearest to history: philosopher, smuggler, serials, butt, rca, mathbb, vorbis, mona,
# Nearest to two: three, five, four, six, eight, seven, one, nine,
# Nearest to may: can, should, rockall, dives, must, midian, agesilaus, encrypt,
# Nearest to that: which, treviso, governorate, who, he, interactionism, marcius, it,
# Nearest to often: berglin, not, balloons, stjepan, they, witchcraft, inputs, curtains,
# Average loss at step 12000: 3.605152
# Average loss at step 14000: 3.567383
# Average loss at step 16000: 3.407024
# Average loss at step 18000: 3.454811
# Average loss at step 20000: 3.535070
# Nearest to been: be, were, become, by, mora, fodder, regained, painting,
# Nearest to if: when, wrote, believe, although, can, is, abdominal, masefield,
# Nearest to first: last, second, anesthetic, during, declension, walters, slow, trimester,
# Nearest to no: any, it, distracting, staphylococcus, legionaries, reykjav, who, brest,
# Nearest to the: their, its, this, a, an, his, any, another,
# Nearest to new: equator, howie, cold, reducible, diffusing, duma, cerebellum, treaty,
# Nearest to called: rugby, tiff, douglass, iu, pity, castes, garage, unfriendly,
# Nearest to his: their, her, its, the, ern, merged, preparation, your,
# Nearest to over: corrections, kaufmann, histogram, liners, caucasian, seif, passage, plaintexts,
# Nearest to after: corrective, before, pln, pacifist, during, acta, when, trailer,
# Nearest to most: wither, phelps, some, more, offline, mortis, process, many,
# Nearest to history: philosopher, serials, smuggler, mathbb, republic, vorbis, kassel, beep,
# Nearest to two: three, four, six, five, one, eight, seven, zero,
# Nearest to may: can, should, would, must, could, will, might, apprenticeship,
# Nearest to that: which, but, also, treviso, governorate, dollar, maus, who,
# Nearest to often: sometimes, berglin, widely, also, who, which, beneath, not,
# Average loss at step 22000: 3.503561
# Average loss at step 24000: 3.492609
# Average loss at step 26000: 3.480816
# Average loss at step 28000: 3.479350
# Average loss at step 30000: 3.501064
# Nearest to been: become, be, mora, was, were, regained, khan, gone,
# Nearest to if: when, although, though, is, wrote, while, where, unpaid,
# Nearest to first: last, second, anesthetic, during, slow, sloan, turing, same,
# Nearest to no: any, reykjav, a, distracting, brest, staphylococcus, only, this,
# Nearest to the: their, its, his, these, some, a, newsletter, ova,
# Nearest to new: howie, equator, radical, burghers, vowed, platypus, particular, spl,
# Nearest to called: replicating, rugby, tiff, moesia, iu, used, pity, douglass,
# Nearest to his: their, her, its, your, s, the, franchisees, ern,
# Nearest to over: corrections, seif, passage, caucasian, conventions, take, plaintexts, kaufmann,
# Nearest to after: before, during, corrective, when, from, pacifist, in, until,
# Nearest to most: more, phelps, some, many, offline, wither, narmada, use,
# Nearest to history: philosopher, serials, republic, mathbb, smuggler, kassel, sock, explosion,
# Nearest to two: three, four, six, five, one, seven, eight, nine,
# Nearest to may: can, would, should, will, must, could, might, cannot,
# Nearest to that: which, but, this, what, treviso, marcius, who, cars,
# Nearest to often: sometimes, generally, also, commonly, usually, widely, still, berglin,
# Average loss at step 32000: 3.501089
# Average loss at step 34000: 3.494286
# Average loss at step 36000: 3.453766
# Average loss at step 38000: 3.301629
# Average loss at step 40000: 3.427049
# Nearest to been: become, be, was, mora, khan, were, swift, formally,
# Nearest to if: when, where, unpaid, is, though, for, although, mashal,
# Nearest to first: last, second, during, turing, anesthetic, reissues, next, walters,
# Nearest to no: any, reykjav, only, staphylococcus, there, than, transshipment, almighty,
# Nearest to the: their, a, his, its, each, sometime, this, bertolucci,
# Nearest to new: cerebellum, equator, radical, burghers, single, howie, turnovers, entering,
# Nearest to called: replicating, named, used, samos, rugby, tiff, douglass, jazzy,
# Nearest to his: their, her, its, your, the, my, vortex, s,
# Nearest to over: corrections, hmso, conventions, starters, out, jehoshaphat, histogram, gum,
# Nearest to after: before, during, corrective, when, apologia, pln, pegs, was,
# Nearest to most: more, less, phelps, forty, blind, among, all, wither,
# Nearest to history: serials, mathbb, library, sciences, philosopher, association, list, ingres,
# Nearest to two: four, three, five, six, seven, eight, one, zero,
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Nearest to that: which, this, what, but, however, it, where, marcius,
# Nearest to often: sometimes, usually, generally, also, commonly, widely, still, who,
# Average loss at step 42000: 3.433314
# Average loss at step 44000: 3.451798
# Average loss at step 46000: 3.448373
# Average loss at step 48000: 3.353883
# Average loss at step 50000: 3.384435
# Nearest to been: become, be, was, were, mora, had, regained, begun,
# Nearest to if: when, though, where, although, before, while, unpaid, after,
# Nearest to first: last, second, next, during, same, anesthetic, latter, younger,
# Nearest to no: any, reykjav, guppy, proscribed, almighty, map, brest, staphylococcus,
# Nearest to the: its, their, some, this, a, his, trends, any,
# Nearest to new: zo, cerebellum, equator, radical, functionals, animation, entering, single,
# Nearest to called: named, replicating, used, extremophiles, alexanderplatz, tsr, xxiv, llama,
# Nearest to his: their, her, its, my, your, him, merged, algerians,
# Nearest to over: corrections, gum, toppings, precisely, out, on, settings, cabell,
# Nearest to after: before, when, during, while, corrective, apologia, pln, from,
# Nearest to most: more, less, many, mujahideen, some, phelps, obtuse, use,
# Nearest to history: sciences, list, pattern, mathbb, library, case, discussion, association,
# Nearest to two: three, four, one, six, five, seven, eight, nine,
# Nearest to may: can, would, should, could, will, must, might, does,
# Nearest to that: which, however, this, what, marcius, treviso, but, often,
# Nearest to often: sometimes, usually, generally, commonly, also, widely, now, still,
# Average loss at step 52000: 3.436065
# Average loss at step 54000: 3.423489
# Average loss at step 56000: 3.440322
# Average loss at step 58000: 3.399201
# Average loss at step 60000: 3.392203
# Nearest to been: become, be, was, mora, gone, were, begun, khan,
# Nearest to if: when, where, though, before, although, since, because, then,
# Nearest to first: last, second, next, same, younger, only, latter, during,
# Nearest to no: any, reykjav, almighty, guppy, a, annoy, brest, mixed,
# Nearest to the: their, its, a, any, biollante, some, this, peacefully,
# Nearest to new: equator, vowed, cerebellum, xbox, manna, spl, particular, abhorrent,
# Nearest to called: replicating, used, named, extremophiles, considered, known, ney, dicrostonyx,
# Nearest to his: their, her, its, my, your, merged, our, the,
# Nearest to over: about, kaufmann, toppings, corrections, out, histogram, around, down,
# Nearest to after: before, during, when, corrective, while, apologia, despite, although,
# Nearest to most: more, many, some, especially, because, less, mujahideen, neopagan,
# Nearest to history: list, pattern, sciences, origin, court, library, discussion, yi,
# Nearest to two: three, four, five, eight, six, seven, one, nine,
# Nearest to may: can, would, should, could, will, must, might, cannot,
# Nearest to that: which, what, this, however, often, marcius, scrabble, expositor,
# Nearest to often: sometimes, usually, generally, commonly, also, frequently, now, widely,
# Average loss at step 62000: 3.244391
# Average loss at step 64000: 3.254089
# Average loss at step 66000: 3.400801
# Average loss at step 68000: 3.396379
# Average loss at step 70000: 3.361765
# Nearest to been: become, be, was, were, gone, already, begun, mora,
# Nearest to if: when, though, where, before, although, since, for, while,
# Nearest to first: last, second, next, same, younger, during, carleton, best,
# Nearest to no: any, than, distracting, brest, only, poppers, almighty, staphylococcus,
# Nearest to the: their, its, this, a, any, these, biollante, each,
# Nearest to new: equator, spl, cerebellum, transcendence, particular, peleus, vowed, howie,
# Nearest to called: replicating, used, named, known, considered, extremophiles, referred, flanagan,
# Nearest to his: her, their, my, its, your, our, merged, franchisees,
# Nearest to over: toppings, about, corrections, gum, around, under, down, patriotic,
# Nearest to after: before, during, corrective, when, while, despite, caspase, apologia,
# Nearest to most: more, less, many, some, especially, because, restless, among,
# Nearest to history: list, discussion, pattern, newsweek, yi, sciences, calorimeter, praises,
# Nearest to two: three, four, six, seven, eight, one, five, zero,
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Nearest to that: which, what, however, but, this, actually, nor, also,
# Nearest to often: sometimes, usually, generally, commonly, now, frequently, typically, also,
# Average loss at step 72000: 3.376121
# Average loss at step 74000: 3.350426
# Average loss at step 76000: 3.329164
# Average loss at step 78000: 3.353980
# Average loss at step 80000: 3.379188
# Nearest to been: become, be, were, was, gone, mora, already, begun,
# Nearest to if: when, though, since, where, before, although, because, cystic,
# Nearest to first: second, last, next, younger, same, highest, third, bump,
# Nearest to no: little, any, guppy, she, echolocation, relations, proscribed, receiver,
# Nearest to the: its, their, his, a, bertolucci, this, another, her,
# Nearest to new: equator, peleus, cerebellum, vowed, howie, particular, zo, outweighs,
# Nearest to called: replicating, named, used, considered, termed, known, referred, ney,
# Nearest to his: her, their, my, its, your, our, the, franchisees,
# Nearest to over: around, under, capricornus, corrections, about, toppings, out, tegmark,
# Nearest to after: before, during, when, corrective, while, despite, without, pds,
# Nearest to most: many, more, less, especially, some, among, americas, all,
# Nearest to history: list, discussion, newsweek, dent, sprengel, yi, kassel, hardship,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to may: can, would, could, should, might, will, must, cannot,
# Nearest to that: which, however, what, but, treviso, this, where, then,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, still, also,
# Average loss at step 82000: 3.407238
# Average loss at step 84000: 3.408983
# Average loss at step 86000: 3.389919
# Average loss at step 88000: 3.351214
# Average loss at step 90000: 3.366015
# Nearest to been: become, be, was, already, mora, begun, previously, had,
# Nearest to if: when, though, where, since, before, although, for, laika,
# Nearest to first: last, second, next, younger, same, eighth, best, highest,
# Nearest to no: little, any, only, echolocation, poppers, than, damage, staphylococcus,
# Nearest to the: its, their, his, this, any, a, each, biollante,
# Nearest to new: zo, equator, single, cerebellum, peleus, outweighs, particular, howie,
# Nearest to called: named, used, replicating, considered, known, termed, referred, flanagan,
# Nearest to his: her, their, its, my, your, our, the, franchisees,
# Nearest to over: around, within, out, sextus, under, down, clinker, corrections,
# Nearest to after: before, during, when, while, corrective, despite, until, without,
# Nearest to most: more, less, many, especially, some, particularly, americas, several,
# Nearest to history: list, newsweek, discussion, sprengel, yi, kassel, origins, hardship,
# Nearest to two: three, four, five, seven, six, eight, one, nine,
# Nearest to may: can, could, should, would, might, must, will, cannot,
# Nearest to that: which, however, but, what, treviso, expositor, also, generally,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, still, widely,
# Average loss at step 92000: 3.399262
# Average loss at step 94000: 3.255438
# Average loss at step 96000: 3.356148
# Average loss at step 98000: 3.244183
# Average loss at step 100000: 3.354019
# Nearest to been: become, be, was, already, had, internalized, aj, mora,
# Nearest to if: when, though, where, before, since, although, for, while,
# Nearest to first: last, second, next, younger, same, third, previous, highest,
# Nearest to no: any, little, brest, only, echolocation, map, flattening, there,
# Nearest to the: their, its, your, his, a, each, this, factional,
# Nearest to new: equator, howie, single, full, outweighs, animation, lublin, cerebellum,
# Nearest to called: named, used, termed, replicating, considered, known, referred, samos,
# Nearest to his: her, their, my, your, its, our, the, s,
# Nearest to over: around, within, jehoshaphat, through, clinker, sextus, encased, advantage,
# Nearest to after: before, during, when, while, without, corrective, despite, afterwards,
# Nearest to most: more, less, especially, many, particularly, among, some, americas,
# Nearest to history: list, sprengel, pattern, dent, discussion, ericaceae, ingres, yi,
# Nearest to two: four, three, five, six, seven, eight, one, zero,
# Nearest to may: can, could, should, must, might, would, will, cannot,
# Nearest to that: which, however, what, scrabble, expositor, treviso, who, whom,
# Nearest to often: sometimes, usually, generally, commonly, typically, frequently, widely, still,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# Data associated with a label is a vector of each surrounding word rather than one-to-one mappings:
# i.e. for [the, dog, barked, at, a, tree]
# skip-gram 2, 1 gets something like [dog, the], [dog, barked], [barked, dog], [barked, at]
# CBOW gets something like [dog, [the barked]], [barked, [dog at]] etc.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# # Make a batch

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    global data_index
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.ndarray)

    for i in range(batch_size):
        buffer = list()
        span_index = data_index
        for _ in range(span):
            buffer.append(data[span_index])
            span_index = (span_index + 1) % len(data)
        target = len(buffer) // 2 # the middle element of the buffer
        #batch_add = np.ndarray(shape=(span - 1), dtype=np.int32)
        to_add = buffer[:target]
        to_add.extend(buffer[(target+1):])
        #batch_add[:] = to_add
        #batch[i] = batch_add
        batch[i, :] = to_add
        labels[i] = buffer[target]
        data_index = (data_index + 1) % len(data)
    labels = labels.reshape(len(labels), 1)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    labels = labels.flatten()
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    for i in range(len(batch)):
        print('label: ', reverse_dictionary[labels[i]])
        print('batch: ', [reverse_dictionary[bi] for bi in batch[i]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 4 and skip_window = 1:
# label:  originated
# batch:  ['anarchism', 'as']
# label:  as
# batch:  ['originated', 'a']
# label:  a
# batch:  ['as', 'term']
# label:  term
# batch:  ['a', 'of']
# label:  of
# batch:  ['term', 'abuse']
# label:  abuse
# batch:  ['of', 'first']
# label:  first
# batch:  ['abuse', 'used']
# label:  used
# batch:  ['first', 'against']
#
# with num_skips = 4 and skip_window = 2:
# label:  as
# batch:  ['anarchism', 'originated', 'a', 'term']
# label:  a
# batch:  ['originated', 'as', 'term', 'of']
# label:  term
# batch:  ['as', 'a', 'of', 'abuse']
# label:  of
# batch:  ['a', 'term', 'abuse', 'first']
# label:  abuse
# batch:  ['term', 'of', 'first', 'used']
# label:  first
# batch:  ['of', 'abuse', 'used', 'against']
# label:  used
# batch:  ['abuse', 'first', 'against', 'early']
# label:  against
# batch:  ['first', 'used', 'early', 'working']

# %% [markdown]
# ## Setup the network

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # More complicated for CBOW
  # BEFORE:
  #embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # AFTER:
  # Get embedding for each word associated with label, average them
  # http://www.thushv.com/natural_language_processing/word2vec-part-2-nlp-with-deep-learning-with-tensorflow-cbow/
  # https://github.com/ankit-ai/udacity_deep_learning_course/blob/master/5_word2vec.ipynb
  #embeds = None
  #for i in range(2 * skip_window):
  #  embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:, i])
  #  print('embedding %d shape: %s'%(i,embedding_i.get_shape().as_list()))
  #  emb_x,emb_y = embedding_i.get_shape().as_list()
  #  if embeds is None:
  #      embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
  #  else:
  #      embeds = tf.concat(2,[embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])])
  # Averaging embeddings accross the full context into a single embedding layer
  context_embeddings = []
  for i in range(2*skip_window):
    context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]))
            
  avg_embed =  tf.reduce_mean(tf.stack(axis=0,values=context_embeddings),0,keep_dims=False) 

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %% [markdown]
# ## Train the model

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.269516
# Nearest to use: trim, lautering, cops, expression, rajiv, roadmap, amistad, skopje,
# Nearest to has: whitish, poison, christianity, depict, sac, endorses, wels, bridged,
# Nearest to will: barred, prevents, pusan, promised, mysticism, radon, kriol, agree,
# Nearest to a: alleges, spokesman, confederates, gresham, arcology, puns, aggregation, booby,
# Nearest to more: stranger, pneumoniae, trader, plasticizers, shortstop, tattoos, taos, ty,
# Nearest to can: chaney, wimbledon, elegiac, beatification, commentarii, mario, churchmen, hif,
# Nearest to if: fatality, soundly, transept, jolla, mandrakelinux, fleece, contact, idiosyncrasies,
# Nearest to zero: strait, highness, demoscene, laodiceans, mathematician, evaluates, antony, fealty,
# Nearest to i: booting, consumes, widowed, willie, diethyl, immaculate, espresso, brienne,
# Nearest to war: approximation, parthia, amplitudes, vivekananda, schafer, seduced, ripple, traveled,
# Nearest to when: mercia, waldensians, haul, carpathians, romanorum, samaria, scan, muons,
# Nearest to years: niven, elegans, stencil, commas, clientele, shear, universitaire, decomposes,
# Nearest to this: kumasi, nhs, statement, flagg, wetlands, shelved, wizardry, waldeck,
# Nearest to such: throne, anticipation, battleships, supplier, roundly, inverted, lambeau, dinosaur,
# Nearest to some: obligated, regular, periphery, octavius, thatcher, pricing, unknowable, sirius,
# Nearest to only: compactly, korea, grammarians, petrovi, gas, favour, warrington, codices,
# Average loss at step 2000: 4.036087
# Average loss at step 4000: 3.508779
# Average loss at step 6000: 3.328464
# Average loss at step 8000: 3.214212
# Average loss at step 10000: 3.131921
# Nearest to use: trim, expression, hopeful, rajiv, bayou, masovia, marston, amistad,
# Nearest to has: had, was, have, is, became, bridged, microscopy, fluency,
# Nearest to will: can, may, would, should, could, did, housewives, might,
# Nearest to a: the, mould, kannada, doughnut, willis, detection, this, another,
# Nearest to more: sunny, considered, kirsten, prima, ivan, submerged, sparky, taos,
# Nearest to can: would, should, must, may, will, could, cannot, amulet,
# Nearest to if: waning, where, fatality, aristotelian, skirts, although, soliloquy, scaffold,
# Nearest to zero: five, eight, nine, four, three, six, seven, broughton,
# Nearest to i: athabasca, booting, d, osborn, brienne, raspberry, fancher, consumes,
# Nearest to war: vivekananda, schafer, amplitudes, approximation, mittag, enlarging, salmon, chromatids,
# Nearest to when: waldseem, fenian, clutching, mercia, before, since, because, where,
# Nearest to years: niven, clientele, donates, elegans, khoikhoi, actinium, astronauts, univac,
# Nearest to this: it, the, her, which, glacial, kumasi, its, lark,
# Nearest to such: well, roundly, battleships, many, immune, dinosaur, wholeheartedly, barricade,
# Nearest to some: many, regular, calculi, keying, these, committees, other, any,
# Nearest to only: rural, korea, mayen, restatement, petrovi, papier, priorities, miranda,
# Average loss at step 12000: 3.153724
# Average loss at step 14000: 3.134014
# Average loss at step 16000: 3.119744
# Average loss at step 18000: 3.107893
# Average loss at step 20000: 2.977420
# Nearest to use: trim, expression, hopeful, evidence, dreamcast, arriving, saltwater, bayou,
# Nearest to has: had, have, was, is, became, bridged, since, soared,
# Nearest to will: can, may, would, should, could, might, cannot, must,
# Nearest to a: kannada, the, mould, any, another, every, no, willis,
# Nearest to more: less, very, most, sunny, considered, barricade, decays, ivan,
# Nearest to can: should, may, would, could, will, must, cannot, might,
# Nearest to if: where, though, scaffold, when, waning, aristotelian, fiery, although,
# Nearest to zero: eight, four, five, six, seven, nine, three, schwenkfeld,
# Nearest to i: you, athabasca, osborn, we, booting, he, consumes, they,
# Nearest to war: vivekananda, schafer, mittag, amplitudes, chromatids, polyphyletic, salmon, continental,
# Nearest to when: before, where, waldseem, if, fenian, under, masoretes, attu,
# Nearest to years: times, donates, niven, clientele, actinium, meters, elegans, univac,
# Nearest to this: it, which, kumasi, that, any, rigour, glacial, gays,
# Nearest to such: well, these, battleships, many, roundly, known, including, like,
# Nearest to some: many, these, regular, any, calculi, those, several, manmade,
# Nearest to only: rural, priorities, papier, galli, mayen, restatement, pannonian, zangger,
# Average loss at step 22000: 3.058003
# Average loss at step 24000: 3.049757
# Average loss at step 26000: 2.965820
# Average loss at step 28000: 3.006844
# Average loss at step 30000: 2.980809
# Nearest to use: trim, bayou, hopeful, evidence, dreamcast, expression, liberals, marston,
# Nearest to has: had, have, was, is, bridged, became, since, includes,
# Nearest to will: would, can, may, could, should, might, cannot, must,
# Nearest to a: another, mould, the, every, any, doughnut, verisign, kannada,
# Nearest to more: less, most, very, longer, sunny, greater, decays, indexes,
# Nearest to can: may, could, would, should, will, must, cannot, might,
# Nearest to if: where, when, though, showtime, fiery, before, scaffold, photius,
# Nearest to zero: eight, seven, six, five, four, nine, three, schwenkfeld,
# Nearest to i: you, athabasca, ii, we, osborn, iii, raspberry, southwestern,
# Nearest to war: vivekananda, schafer, mittag, galilei, basso, chromatids, polyphyletic, containers,
# Nearest to when: if, before, after, where, timetable, towards, because, while,
# Nearest to years: times, days, minutes, donates, niven, clientele, hours, meters,
# Nearest to this: which, it, that, gays, waldeck, some, the, sorbonne,
# Nearest to such: well, these, many, known, including, like, barricade, battleships,
# Nearest to some: many, these, several, any, those, calculi, manmade, mormons,
# Nearest to only: rural, always, heliogabalus, still, pannonian, cypriot, papier, restatement,
# Average loss at step 32000: 2.972115
# Average loss at step 34000: 2.815163
# Average loss at step 36000: 2.938199
# Average loss at step 38000: 2.934921
# Average loss at step 40000: 2.921011
# Nearest to use: trim, bayou, endure, expression, dreamcast, liberals, evidence, bahamian,
# Nearest to has: had, have, was, is, includes, contain, bridged, riffing,
# Nearest to will: would, may, can, might, should, could, must, cannot,
# Nearest to a: another, every, the, athenaeus, doughnut, willis, kannada, mould,
# Nearest to more: less, most, very, longer, greater, better, highly, rather,
# Nearest to can: may, could, will, would, should, must, cannot, might,
# Nearest to if: when, where, photius, fiery, showtime, scaffold, before, though,
# Nearest to zero: five, four, seven, six, eight, nine, three, two,
# Nearest to i: you, ii, iii, we, athabasca, southwestern, osborn, wall,
# Nearest to war: vivekananda, mittag, schafer, romanus, traveled, galilei, basso, amplitudes,
# Nearest to when: if, after, before, because, where, timetable, while, today,
# Nearest to years: days, minutes, times, hours, months, decades, niven, clientele,
# Nearest to this: which, it, what, considerable, that, brugge, there, ambient,
# Nearest to such: well, these, known, effectively, including, many, barricade, follows,
# Nearest to some: many, several, these, any, those, manmade, mormons, various,
# Nearest to only: always, rural, papier, pannonian, mayen, heliogabalus, just, still,
# Average loss at step 42000: 2.913091
# Average loss at step 44000: 2.958090
# Average loss at step 46000: 2.910832
# Average loss at step 48000: 2.910271
# Average loss at step 50000: 2.838548
# Nearest to use: bayou, trim, endure, case, need, retreat, dreamcast, rajiv,
# Nearest to has: had, have, is, was, bridged, includes, frau, since,
# Nearest to will: would, can, could, may, might, should, must, cannot,
# Nearest to a: the, another, every, willis, athenaeus, any, kannada, rapport,
# Nearest to more: less, most, very, longer, highly, greater, rather, extremely,
# Nearest to can: may, could, will, should, must, would, might, cannot,
# Nearest to if: when, where, though, photius, before, showtime, fiery, scaffold,
# Nearest to zero: eight, four, seven, five, nine, three, six, colspan,
# Nearest to i: you, we, ii, athabasca, southwestern, iii, raspberry, hastily,
# Nearest to war: vivekananda, mittag, schafer, basso, wars, galilei, fielding, romanus,
# Nearest to when: if, after, before, where, because, while, towards, during,
# Nearest to years: days, minutes, hours, decades, months, times, niven, clientele,
# Nearest to this: which, it, some, the, ambient, any, what, brugge,
# Nearest to such: well, these, known, many, barricade, follows, effectively, regarded,
# Nearest to some: many, several, these, any, certain, various, this, those,
# Nearest to only: always, still, heliogabalus, just, papier, pannonian, offerings, rural,
# Average loss at step 52000: 2.837703
# Average loss at step 54000: 2.867044
# Average loss at step 56000: 2.882206
# Average loss at step 58000: 2.738337
# Average loss at step 60000: 2.820633
# Nearest to use: need, bayou, endure, rajiv, dreamcast, trim, retreat, houser,
# Nearest to has: had, have, is, was, includes, having, microscopy, centimes,
# Nearest to will: would, can, could, might, should, may, must, cannot,
# Nearest to a: another, the, athenaeus, rapport, every, mould, willis, polyhedral,
# Nearest to more: less, most, very, longer, highly, greater, rather, stronger,
# Nearest to can: could, may, will, must, should, would, cannot, might,
# Nearest to if: when, where, showtime, fiery, photius, though, before, without,
# Nearest to zero: five, seven, nine, four, six, eight, three, colspan,
# Nearest to i: you, ii, we, athabasca, southwestern, laguna, practically, iii,
# Nearest to war: vivekananda, wars, mittag, galilei, schafer, amplitudes, fluctuated, chromatids,
# Nearest to when: if, after, before, where, while, during, because, although,
# Nearest to years: days, minutes, months, decades, hours, times, year, centuries,
# Nearest to this: which, it, the, some, ambient, rigour, any, kgb,
# Nearest to such: these, well, known, follows, including, many, defined, effectively,
# Nearest to some: many, several, these, certain, those, most, any, various,
# Nearest to only: always, still, offerings, heliogabalus, papier, just, cypriot, neisse,
# Average loss at step 62000: 2.847495
# Average loss at step 64000: 2.829663
# Average loss at step 66000: 2.713556
# Average loss at step 68000: 2.741936
# Average loss at step 70000: 2.767387
# Nearest to use: need, bayou, acceptance, dreamcast, endure, houser, end, basis,
# Nearest to has: had, have, is, was, includes, having, microscopy, ergot,
# Nearest to will: would, can, should, might, may, could, must, cannot,
# Nearest to a: another, any, every, the, localised, doughnut, jersey, athenaeus,
# Nearest to more: less, most, very, longer, stronger, greater, highly, rather,
# Nearest to can: could, may, will, must, cannot, should, might, would,
# Nearest to if: when, where, showtime, though, before, fiery, after, photius,
# Nearest to zero: eight, six, five, four, seven, nine, three, colspan,
# Nearest to i: you, we, ii, southwestern, athabasca, laguna, iii, they,
# Nearest to war: vivekananda, wars, mittag, coppola, fielding, galilei, schafer, fluctuated,
# Nearest to when: if, after, where, during, before, while, because, unless,
# Nearest to years: days, minutes, months, decades, times, hours, centuries, year,
# Nearest to this: which, it, the, any, adour, tahitian, that, luxor,
# Nearest to such: these, well, follows, known, certain, barricade, defined, regarded,
# Nearest to some: many, several, certain, these, most, various, numerous, those,
# Nearest to only: always, still, just, offerings, neisse, cypriot, heliogabalus, easily,
# Average loss at step 72000: 2.760359
# Average loss at step 74000: 2.786999
# Average loss at step 76000: 2.666470
# Average loss at step 78000: 2.798394
# Average loss at step 80000: 2.811797
# Nearest to use: acceptance, need, bayou, dreamcast, endure, houser, encodings, presence,
# Nearest to has: had, have, was, is, having, includes, microscopy, contains,
# Nearest to will: would, can, should, might, could, may, must, cannot,
# Nearest to a: another, the, any, every, athenaeus, willis, mould, doughnut,
# Nearest to more: less, most, very, highly, longer, stronger, greater, particularly,
# Nearest to can: could, may, will, must, cannot, should, would, might,
# Nearest to if: when, where, though, before, showtime, fiery, photius, unless,
# Nearest to zero: five, eight, six, seven, four, nine, three, colspan,
# Nearest to i: you, we, ii, they, athabasca, southwestern, boas, laguna,
# Nearest to war: vivekananda, wars, mittag, galilei, coppola, fielding, elegance, amplitudes,
# Nearest to when: if, after, before, during, while, although, where, because,
# Nearest to years: minutes, days, months, decades, hours, times, centuries, weeks,
# Nearest to this: which, it, some, rigour, sorbonne, tahitian, the, ambient,
# Nearest to such: well, these, follows, certain, known, described, many, viewed,
# Nearest to some: many, several, certain, these, various, any, numerous, most,
# Nearest to only: always, just, cypriot, still, offerings, actually, heliogabalus, pannonian,
# Average loss at step 82000: 2.769628
# Average loss at step 84000: 2.683530
# Average loss at step 86000: 2.765340
# Average loss at step 88000: 2.737128
# Average loss at step 90000: 2.753281
# Nearest to use: acceptance, dreamcast, need, bayou, pieces, fines, synchronize, perugia,
# Nearest to has: had, have, is, was, having, microscopy, includes, kabaddi,
# Nearest to will: would, can, should, might, could, may, must, cannot,
# Nearest to a: another, the, every, athenaeus, doughnut, willis, localised, hw,
# Nearest to more: less, most, very, highly, longer, stronger, fairly, greater,
# Nearest to can: could, will, may, should, cannot, must, would, might,
# Nearest to if: when, where, though, before, showtime, unless, since, after,
# Nearest to zero: seven, eight, six, five, four, nine, three, colspan,
# Nearest to i: you, ii, we, iii, practically, southwestern, athabasca, they,
# Nearest to war: vivekananda, wars, mittag, coppola, galilei, fielding, elegance, schafer,
# Nearest to when: if, after, before, while, because, although, where, unless,
# Nearest to years: minutes, days, months, decades, hours, centuries, times, weeks,
# Nearest to this: which, it, rigour, another, tahitian, sorbonne, glacial, herein,
# Nearest to such: these, well, follows, known, certain, beeching, described, viewed,
# Nearest to some: many, several, certain, various, numerous, these, most, any,
# Nearest to only: always, just, either, actually, necessarily, heliogabalus, still, easily,
# Average loss at step 92000: 2.743539
# Average loss at step 94000: 2.665676
# Average loss at step 96000: 2.737640
# Average loss at step 98000: 2.697260
# Average loss at step 100000: 2.457598
# Nearest to use: bayou, perugia, endure, pieces, acceptance, dreamcast, amphetamines, recipe,
# Nearest to has: had, have, is, was, having, includes, provides, frau,
# Nearest to will: would, can, should, might, could, must, may, cannot,
# Nearest to a: another, the, lynyrd, every, doughnut, longships, athenaeus, unrealistic,
# Nearest to more: less, most, very, longer, stronger, highly, greater, faster,
# Nearest to can: could, will, may, should, cannot, must, might, would,
# Nearest to if: when, though, where, before, unless, showtime, since, query,
# Nearest to zero: four, five, six, seven, eight, nine, three, two,
# Nearest to i: you, we, ii, iii, athabasca, southwestern, kolbin, boas,
# Nearest to war: vivekananda, wars, mittag, coppola, galilei, elegance, chromatids, fielding,
# Nearest to when: if, after, before, while, during, unless, although, where,
# Nearest to years: days, minutes, decades, months, hours, weeks, centuries, year,
# Nearest to this: which, it, each, some, another, ongoing, xxxx, wpa,
# Nearest to such: these, well, follows, certain, known, viewed, beeching, americanized,
# Nearest to some: many, several, certain, numerous, various, these, most, those,
# Nearest to only: always, heliogabalus, either, just, necessarily, cypriot, repealed, actually,
